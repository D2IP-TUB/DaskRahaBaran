# %% [markdown]
# # End-to-End Data Cleaning Pipeline with Raha and Baran (Minimal and Sequential)
# We build an end-to-end data cleaning pipeline with our configuration-free error detection and correction systems, Raha and Baran.

# %%
import pandas
import IPython.display

import raha

# %% [markdown]
# ## Error Detection with Raha

# %% [markdown]
# ### 1. Instantiating the Detection Class
# We first instantiate the `Detection` class.

# %%
app_1 = raha.dask_version.detection_parallel.Detection()

# How many tuples would you label?
app_1.LABELING_BUDGET = 20

# Would you like to see the logs?
app_1.VERBOSE = True

# %% [markdown]
# ### 2. Instantiating the Dataset
# We next load and instantiate the dataset object.

# %%
dataset_dictionary = {
    "name": "tax",
    "path": "../datasets/tax/dirty.csv",
    "clean_path": "../datasets/tax/clean.csv"
}
d = app_1.initialize_dataset(dataset_dictionary)
d.dataframe.head()
# Out:
#       f_name    l_name gender area_code     phone        city state    zip
# 0   Pengyuan   Zendler      F       508  744-9007  SWAMPSCOTT    MA  01907  \
# 1        Nik     Tacic      M       702  517-7658   LAS VEGAS    NV  89140
# 2      Hovav    Punter      M       501  304-9763       HASTY    AR  72640
# 3  Xiangning  Vanneste      F       862  651-6469  BRIGANTINE    NJ  08203
# 4      Belen    Niccum      F       920  287-1889    FLORENCE    WI  54121
#
#   marital_status has_child salary       rate single_exemp married_exemp
# 0              M         N  90000        5.3            0          7150  \
# 1              M         N  90000        0.0            0             0
# 2              S         N  50000        7.0           20             0
# 3              M         Y  55000  1.9519792            0          2000
# 4              S         Y  85000  5.9232907          700             0
#
#   child_exemp
# 0           0
# 1           0
# 2           0
# 3        1500
# 4         400

# %% [markdown]
# ### 3. Running Error Detection Strategies
# Raha runs (all or the promising) error detection strategies on the dataset. This step could take a while because all the strategies should be run on the dataset.

# %%
app_1.run_strategies(d)
# Out:
# 3743 cells are detected by ["PVD", ["l_name", "E"]].
# 27473 cells are detected by ["PVD", ["city", "K"]].
# 3786 cells are detected by ["PVD", ["single_exemp", "8"]].
# 199813 cells are detected by ["PVD", ["rate", "."]].
# 4347 cells are detected by ["PVD", ["l_name", "V"]].
# 27718 cells are detected by ["PVD", ["f_name", "g"]].
#
# 11069 cells are detected by ["PVD", ["l_name", "p"]].107027 cells are detected by ["PVD", ["phone", "8"]].
# 47015 cells are detected by ["PVD", ["city", "D"]].
# 19366 cells are detected by ["PVD", ["state", "O"]].
# 4223 cells are detected by ["PVD", ["f_name", "V"]].
# 23531 cells are detected by ["PVD", ["single_exemp", "2"]].
# 400000 cells are detected by ["RVD", ["has_child", "l_name"]].
# 13616 cells are detected by ["PVD", ["single_exemp", "7"]].
# 9260 cells are detected by ["RVD", ["phone", "salary"]].
# 113770 cells are detected by ["PVD", ["f_name", "a"]].
# 399600 cells are detected by ["RVD", ["child_exemp", "married_exemp"]].
# 400000 cells are detected by ["RVD", ["marital_status", "city"]].
# 292416 cells are detected by ["RVD", ["area_code", "married_exemp"]].
# 10196 cells are detected by ["PVD", ["l_name", "L"]].
# 400000 cells are detected by ["RVD", ["has_child", "zip"]].
# 400000 cells are detected by ["RVD", ["state", "has_child"]].
# 357844 cells are detected by ["RVD", ["zip", "marital_status"]].
# 3565 cells are detected by ["PVD", ["city", "X"]].
# 28923 cells are detected by ["PVD", ["single_exemp", "1"]].
# 11525 cells are detected by ["PVD", ["state", "H"]].
# 266102 cells are detected by ["RVD", ["zip", "child_exemp"]].
# 5640 cells are detected by ["PVD", ["l_name", "F"]].
# 400000 cells are detected by ["RVD", ["has_child", "rate"]].
# 99451 cells are detected by ["PVD", ["zip", "0"]].
# 15184 cells are detected by ["PVD", ["f_name", "A"]].
# 256642 cells are detected by ["RVD", ["single_exemp", "marital_status"]].
# 338656 cells are detected by ["RVD", ["city", "area_code"]].
# 254430 cells are detected by ["RVD", ["married_exemp", "single_exemp"]].
# 19353 cells are detected by ["PVD", ["married_exemp", "6"]].
# 9740 cells are detected by ["RVD", ["phone", "area_code"]].
# 107594 cells are detected by ["PVD", ["city", "O"]].
# 4810 cells are detected by ["RVD", ["phone", "marital_status"]].
# 400000 cells are detected by ["RVD", ["gender", "has_child"]].
# 400000 cells are detected by ["RVD", ["l_name", "zip"]].
# 400000 cells are detected by ["RVD", ["f_name", "l_name"]].
# 55550 cells are detected by ["PVD", ["l_name", "s"]].
# 9896 cells are detected by ["PVD", ["f_name", "R"]].
# 31979 cells are detected by ["PVD", ["area_code", "9"]].
# 106768 cells are detected by ["PVD", ["phone", "4"]].
# 389356 cells are detected by ["RVD", ["zip", "l_name"]].
# 83884 cells are detected by ["PVD", ["zip", "3"]].
# 8843 cells are detected by ["PVD", ["f_name", "G"]].
# 106812 cells are detected by ["PVD", ["phone", "9"]].
# 15274 cells are detected by ["PVD", ["state", "L"]].
# 24704 cells are detected by ["PVD", ["l_name", "g"]].
# 1258 cells are detected by ["PVD", ["l_name", "x"]].
# 42285 cells are detected by ["PVD", ["state", "N"]].
# 27124 cells are detected by ["PVD", ["city", "V"]].
# 63412 cells are detected by ["PVD", ["f_name", "r"]].
# 8404 cells are detected by ["PVD", ["f_name", "Y"]].
# 400000 cells are detected by ["RVD", ["f_name", "city"]].
# 400000 cells are detected by ["RVD", ["child_exemp", "phone"]].
# 5790 cells are detected by ["RVD", ["phone", "child_exemp"]].
# 8810 cells are detected by ["PVD", ["f_name", "C"]].
# 86667 cells are detected by ["PVD", ["zip", "2"]].
# 400000 cells are detected by ["RVD", ["rate", "phone"]].
# 49106 cells are detected by ["PVD", ["city", "H"]].
# 196198 cells are detected by ["PVD", ["married_exemp", "0"]].
# 400000 cells are detected by ["RVD", ["gender", "area_code"]].
# 400000 cells are detected by ["RVD", ["has_child", "child_exemp"]].
# 78113 cells are detected by ["PVD", ["l_name", "n"]].
# 305596 cells are detected by ["RVD", ["rate", "salary"]].
# 400000 cells are detected by ["RVD", ["marital_status", "salary"]].
# 106426 cells are detected by ["PVD", ["phone", "1"]].
# 34648 cells are detected by ["PVD", ["f_name", "t"]].
# 57746 cells are detected by ["PVD", ["l_name", "l"]].
# 396490 cells are detected by ["RVD", ["city", "f_name"]].
# 254430 cells are detected by ["RVD", ["married_exemp", "marital_status"]].
# 38897 cells are detected by ["PVD", ["f_name", "l"]].
# 400000 cells are detected by ["RVD", ["has_child", "gender"]].
# 400000 cells are detected by ["RVD", ["f_name", "phone"]].
# 384752 cells are detected by ["RVD", ["married_exemp", "state"]].
# 75507 cells are detected by ["PVD", ["f_name", "e"]].
# 11942 cells are detected by ["PVD", ["l_name", "P"]].
# 3920 cells are detected by ["PVD", ["state", "U"]].
# 99326 cells are detected by ["PVD", ["gender", "M"]].
# 11453 cells are detected by ["PVD", ["child_exemp", "5"]].
# 9570 cells are detected by ["PVD", ["child_exemp", "4"]].
# 76255 cells are detected by ["PVD", ["zip", "1"]].
# 300158 cells are detected by ["RVD", ["area_code", "child_exemp"]].
# 400000 cells are detected by ["RVD", ["salary", "marital_status"]].
# 11455 cells are detected by ["PVD", ["married_exemp", "1"]].
# 400000 cells are detected by ["RVD", ["l_name", "phone"]].
# 11340 cells are detected by ["PVD", ["married_exemp", "8"]].
# 109716 cells are detected by ["PVD", ["rate", "0"]].
# 20094 cells are detected by ["PVD", ["salary", "6"]].
# 19884 cells are detected by ["PVD", ["salary", "7"]].
# 396084 cells are detected by ["RVD", ["city", "salary"]].
# 400000 cells are detected by ["RVD", ["rate", "f_name"]].
# 30745 cells are detected by ["PVD", ["child_exemp", "1"]].
# 11264 cells are detected by ["PVD", ["state", "E"]].
# 268730 cells are detected by ["RVD", ["zip", "single_exemp"]].
# 25383 cells are detected by ["PVD", ["f_name", "m"]].
# 9740 cells are detected by ["RVD", ["phone", "l_name"]].
# 30278 cells are detected by ["PVD", ["l_name", "k"]].
# 400000 cells are detected by ["RVD", ["l_name", "f_name"]].
# 920 cells are detected by ["PVD", ["f_name", "Q"]].
# 400000 cells are detected by ["RVD", ["state", "marital_status"]].
# 99754 cells are detected by ["PVD", ["marital_status", "M"]].
# 19971 cells are detected by ["PVD", ["salary", "4"]].
# 388000 cells are detected by ["RVD", ["zip", "salary"]].
# 11454 cells are detected by ["PVD", ["l_name", "G"]].
# 7422 cells are detected by ["PVD", ["f_name", "D"]].
# 19821 cells are detected by ["PVD", ["salary", "3"]].
# 8170 cells are detected by ["PVD", ["l_name", "T"]].
# 10491 cells are detected by ["PVD", ["f_name", "H"]].
# 400000 cells are detected by ["RVD", ["area_code", "city"]].
# 171244 cells are detected by ["KBVD", "/home/julian/Desktop/HiWi/DaskRahaBaran/raha/original/tools/KATARA/knowledge-base/zipHasCity.rel.txt"].
# 399824 cells are detected by ["RVD", ["f_name", "single_exemp"]].
# 400000 cells are detected by ["RVD", ["gender", "marital_status"]].
# 400000 cells are detected by ["RVD", ["has_child", "marital_status"]].
# 5834 cells are detected by ["PVD", ["f_name", "w"]].
# 400000 cells are detected by ["RVD", ["has_child", "area_code"]].
# 90486 cells are detected by ["PVD", ["city", "I"]].
# 26489 cells are detected by ["PVD", ["city", "Y"]].
# 28329 cells are detected by ["PVD", ["l_name", "m"]].
# 400000 cells are detected by ["RVD", ["salary", "rate"]].
# 1535 cells are detected by ["PVD", ["city", "Q"]].
# 385196 cells are detected by ["RVD", ["city", "gender"]].
# 32199 cells are detected by ["PVD", ["rate", "2"]].
# 109791 cells are detected by ["PVD", ["city", "N"]].
# 400000 cells are detected by ["RVD", ["gender", "single_exemp"]].
# 15367 cells are detected by ["PVD", ["state", "V"]].
# 194264 cells are detected by ["PVD", ["child_exemp", "0"]].
# 327566 cells are detected by ["RVD", ["area_code", "state"]].
# 22176 cells are detected by ["PVD", ["f_name", "y"]].
# 20299 cells are detected by ["PVD", ["salary", "9"]].
# 380426 cells are detected by ["RVD", ["single_exemp", "area_code"]].
# 71381 cells are detected by ["PVD", ["l_name", "o"]].
# 400000 cells are detected by ["RVD", ["marital_status", "zip"]].
# 187794 cells are detected by ["RVD", ["zip", "rate"]].
# 15347 cells are detected by ["PVD", ["state", "S"]].
# 40018 cells are detected by ["PVD", ["rate", "9"]].
# 60051 cells are detected by ["PVD", ["area_code", "2"]].
# 380850 cells are detected by ["RVD", ["married_exemp", "area_code"]].
# 6483 cells are detected by ["PVD", ["l_name", "W"]].
# 96774 cells are detected by ["PVD", ["city", "R"]].
# 400000 cells are detected by ["RVD", ["child_exemp", "city"]].
# 18553 cells are detected by ["PVD", ["l_name", "B"]].
# 9532 cells are detected by ["RVD", ["zip", "state"]].
# 47069 cells are detected by ["PVD", ["f_name", "h"]].
# 400000 cells are detected by ["RVD", ["single_exemp", "has_child"]].
# 400000 cells are detected by ["RVD", ["has_child", "phone"]].
# 400000 cells are detected by ["RVD", ["gender", "phone"]].
# 400000 cells are detected by ["RVD", ["married_exemp", "l_name"]].
# 400000 cells are detected by ["RVD", ["area_code", "marital_status"]].
# 7951 cells are detected by ["PVD", ["l_name", "f"]].
# 400000 cells are detected by ["RVD", ["rate", "city"]].
# 400000 cells are detected by ["RVD", ["salary", "gender"]].
# 357922 cells are detected by ["RVD", ["zip", "has_child"]].
# 22834 cells are detected by ["PVD", ["state", "D"]].
# 71867 cells are detected by ["PVD", ["rate", "5"]].
# 218 cells are detected by ["PVD", ["city", "-"]].
# 5848 cells are detected by ["PVD", ["child_exemp", "9"]].
# 1725 cells are detected by ["PVD", ["f_name", "x"]].
# 10455 cells are detected by ["PVD", ["f_name", "j"]].
# 9992 cells are detected by ["PVD", ["l_name", "D"]].
# 9740 cells are detected by ["RVD", ["phone", "f_name"]].
# 400000 cells are detected by ["RVD", ["salary", "married_exemp"]].
# 26902 cells are detected by ["PVD", ["child_exemp", "3"]].
# 399812 cells are detected by ["RVD", ["l_name", "child_exemp"]].
# 29118 cells are detected by ["PVD", ["l_name", "d"]].
# 400000 cells are detected by ["RVD", ["salary", "l_name"]].
# 292654 cells are detected by ["RVD", ["state", "married_exemp"]].
# 20035 cells are detected by ["PVD", ["salary", "2"]].
# 1559 cells are detected by ["PVD", ["l_name", "U"]].
# 384138 cells are detected by ["RVD", ["rate", "child_exemp"]].
# 400000 cells are detected by ["RVD", ["single_exemp", "city"]].
# 22 cells are detected by ["PVD", ["l_name", ";"]].
# 400000 cells are detected by ["RVD", ["single_exemp", "l_name"]].
# 400000 cells are detected by ["RVD", ["area_code", "zip"]].
# 12111 cells are detected by ["PVD", ["l_name", "z"]].
# 400000 cells are detected by ["RVD", ["gender", "rate"]].
# 112617 cells are detected by ["PVD", ["area_code", "0"]].
# 400000 cells are detected by ["RVD", ["salary", "has_child"]].
# 77246 cells are detected by ["PVD", ["zip", "6"]].
# 106711 cells are detected by ["PVD", ["phone", "6"]].
# 43279 cells are detected by ["PVD", ["l_name", "u"]].
# 200 cells are detected by ["PVD", ["single_exemp", "*"]].
# 106831 cells are detected by ["PVD", ["phone", "2"]].
# 400000 cells are detected by ["RVD", ["marital_status", "f_name"]].
# 32639 cells are detected by ["PVD", ["l_name", "c"]].
# 187 cells are detected by ["PVD", ["rate", "a"]].
# 79410 cells are detected by ["PVD", ["city", "S"]].
# 9648 cells are detected by ["PVD", ["single_exemp", "4"]].
# 6811 cells are detected by ["PVD", ["f_name", "N"]].
# 400000 cells are detected by ["RVD", ["has_child", "married_exemp"]].
# 400000 cells are detected by ["RVD", ["area_code", "salary"]].
# 400000 cells are detected by ["RVD", ["gender", "salary"]].
# 399600 cells are detected by ["RVD", ["single_exemp", "state"]].
# 400000 cells are detected by ["RVD", ["l_name", "city"]].
# 400000 cells are detected by ["RVD", ["single_exemp", "gender"]].
# 42917 cells are detected by ["PVD", ["l_name", "h"]].
# 400000 cells are detected by ["RVD", ["has_child", "single_exemp"]].
# 5818 cells are detected by ["PVD", ["f_name", "f"]].
# 322033 cells are detected by ["OD", ["histogram", "0.9", "0.5"]].
# 15351 cells are detected by ["PVD", ["single_exemp", "5"]].
# 11492 cells are detected by ["PVD", ["f_name", "K"]].
# 292416 cells are detected by ["RVD", ["rate", "married_exemp"]].
# 400000 cells are detected by ["RVD", ["child_exemp", "marital_status"]].
# 47242 cells are detected by ["PVD", ["rate", "4"]].
# 48000 cells are detected by ["PVD", ["area_code", "5"]].
# 60561 cells are detected by ["PVD", ["rate", "3"]].
# 22006 cells are detected by ["PVD", ["f_name", "k"]].
# 284716 cells are detected by ["RVD", ["state", "area_code"]].
# 26837 cells are detected by ["PVD", ["married_exemp", "4"]].
# 400000 cells are detected by ["RVD", ["f_name", "area_code"]].
# 14045 cells are detected by ["PVD", ["l_name", "K"]].
# 79275 cells are detected by ["PVD", ["zip", "4"]].
# 395738 cells are detected by ["RVD", ["single_exemp", "child_exemp"]].
# 400000 cells are detected by ["RVD", ["f_name", "zip"]].
# 22966 cells are detected by ["PVD", ["single_exemp", "3"]].
# 400000 cells are detected by ["RVD", ["has_child", "state"]].
# 9740 cells are detected by ["RVD", ["phone", "zip"]].
# 52587 cells are detected by ["PVD", ["area_code", "1"]].
# 400000 cells are detected by ["RVD", ["gender", "state"]].
# 246750 cells are detected by ["RVD", ["area_code", "rate"]].
# 384934 cells are detected by ["RVD", ["city", "has_child"]].
# 6118 cells are detected by ["PVD", ["f_name", "p"]].
# 232560 cells are detected by ["RVD", ["city", "state"]].
# 400000 cells are detected by ["RVD", ["state", "l_name"]].
# 6135 cells are detected by ["PVD", ["f_name", "E"]].
# 400000 cells are detected by ["RVD", ["state", "city"]].
# 399886 cells are detected by ["RVD", ["l_name", "married_exemp"]].
# 23365 cells are detected by ["PVD", ["state", "T"]].
# 400000 cells are detected by ["RVD", ["f_name", "state"]].
# 400000 cells are detected by ["RVD", ["salary", "city"]].
# 10191 cells are detected by ["PVD", ["l_name", "H"]].
# 46017 cells are detected by ["PVD", ["state", "A"]].
# 45898 cells are detected by ["PVD", ["city", " "]].
# 694 cells are detected by ["PVD", ["l_name", "'"]].
# 187 cells are detected by ["PVD", ["rate", "N"]].
# 86553 cells are detected by ["PVD", ["f_name", "n"]].
# 85417 cells are detected by ["PVD", ["zip", "8"]].
# 100246 cells are detected by ["PVD", ["marital_status", "S"]].
# 400000 cells are detected by ["RVD", ["marital_status", "single_exemp"]].
# 106431 cells are detected by ["PVD", ["phone", "7"]].
# 400000 cells are detected by ["RVD", ["child_exemp", "gender"]].
# 49483 cells are detected by ["PVD", ["rate", "7"]].
# 385246 cells are detected by ["RVD", ["city", "marital_status"]].
# 98763 cells are detected by ["OD", ["histogram", "0.9", "0.1"]].
# 376670 cells are detected by ["RVD", ["rate", "single_exemp"]].
# 252754 cells are detected by ["RVD", ["single_exemp", "married_exemp"]].
# 24715 cells are detected by ["PVD", ["married_exemp", "2"]].
# 400000 cells are detected by ["RVD", ["single_exemp", "f_name"]].
# 400000 cells are detected by ["RVD", ["married_exemp", "f_name"]].
# 67292 cells are detected by ["PVD", ["f_name", "o"]].
# 400000 cells are detected by ["RVD", ["f_name", "rate"]].
# 400000 cells are detected by ["RVD", ["child_exemp", "salary"]].
# 9883 cells are detected by ["PVD", ["l_name", "w"]].
# 5672 cells are detected by ["RVD", ["phone", "married_exemp"]].
# 38498 cells are detected by ["PVD", ["city", "U"]].
# 192320 cells are detected by ["PVD", ["single_exemp", "0"]].
# 400000 cells are detected by ["RVD", ["gender", "l_name"]].
# 5819 cells are detected by ["PVD", ["single_exemp", "9"]].
# 300092 cells are detected by ["RVD", ["area_code", "single_exemp"]].
# 400000 cells are detected by ["RVD", ["married_exemp", "phone"]].
# 5775 cells are detected by ["PVD", ["married_exemp", "3"]].
# 399600 cells are detected by ["RVD", ["child_exemp", "single_exemp"]].
# 400000 cells are detected by ["RVD", ["single_exemp", "salary"]].
# 400000 cells are detected by ["RVD", ["state", "f_name"]].
# 11645 cells are detected by ["PVD", ["state", "Y"]].
# 400000 cells are detected by ["RVD", ["state", "phone"]].
# 380406 cells are detected by ["RVD", ["single_exemp", "rate"]].
# 32013 cells are detected by ["OD", ["gaussian", "2.7"]].
# 1318 cells are detected by ["RVD", ["zip", "city"]].
# 358098 cells are detected by ["RVD", ["zip", "gender"]].
# 106138 cells are detected by ["PVD", ["phone", "3"]].
# 3882 cells are detected by ["PVD", ["state", "G"]].
# 55227 cells are detected by ["PVD", ["area_code", "7"]].
# 9491 cells are detected by ["PVD", ["f_name", "v"]].
# 105118 cells are detected by ["PVD", ["l_name", "e"]].
# 3364 cells are detected by ["PVD", ["f_name", "Z"]].
# 3801 cells are detected by ["PVD", ["state", "F"]].
# 20051 cells are detected by ["PVD", ["salary", "8"]].
# 299966 cells are detected by ["RVD", ["state", "child_exemp"]].
# 7718 cells are detected by ["PVD", ["married_exemp", "7"]].
# 46110 cells are detected by ["PVD", ["area_code", "6"]].
# 21126 cells are detected by ["PVD", ["child_exemp", "2"]].
#
# 200 cells are detected by ["PVD", ["state", "-"]].199508 cells are detected by ["RVD", ["marital_status", "married_exemp"]].
# 11285 cells are detected by ["PVD", ["f_name", "J"]].
# 247058 cells are detected by ["RVD", ["state", "rate"]].
# 1939 cells are detected by ["PVD", ["child_exemp", "8"]].
# 98763 cells are detected by ["OD", ["histogram", "0.7", "0.1"]].
# 832 cells are detected by ["PVD", ["l_name", "q"]].
# 399804 cells are detected by ["RVD", ["f_name", "child_exemp"]].
# 272 cells are detected by ["PVD", ["f_name", "'"]].
# 400000 cells are detected by ["RVD", ["state", "salary"]].
# 81316 cells are detected by ["PVD", ["city", "T"]].
# 17930 cells are detected by ["PVD", ["l_name", "y"]].
# 558 cells are detected by ["PVD", ["l_name", "Q"]].
# 5104 cells are detected by ["PVD", ["l_name", "N"]].
# 400000 cells are detected by ["RVD", ["has_child", "f_name"]].
# 400000 cells are detected by ["RVD", ["rate", "has_child"]].
# 400000 cells are detected by ["RVD", ["salary", "zip"]].
# 1 cells are detected by ["PVD", ["city", "/"]].
# 400000 cells are detected by ["RVD", ["gender", "f_name"]].
# 0 cells are detected by ["RVD", ["f_name", "gender"]].
# 9640 cells are detected by ["RVD", ["phone", "state"]].
# 200 cells are detected by ["PVD", ["child_exemp", "-"]].
# 1856 cells are detected by ["PVD", ["city", "Z"]].
# 164353 cells are detected by ["OD", ["histogram", "0.1", "0.1"]].
# 83040 cells are detected by ["PVD", ["zip", "5"]].
# 200 cells are detected by ["PVD", ["city", "*"]].
# 11558 cells are detected by ["PVD", ["married_exemp", "5"]].
# 400000 cells are detected by ["RVD", ["child_exemp", "f_name"]].
# 33987 cells are detected by ["PVD", ["city", "B"]].
# 400000 cells are detected by ["RVD", ["has_child", "city"]].
# 400000 cells are detected by ["RVD", ["gender", "child_exemp"]].
# 400000 cells are detected by ["RVD", ["marital_status", "rate"]].
# 400000 cells are detected by ["RVD", ["marital_status", "has_child"]].
# 56203 cells are detected by ["PVD", ["area_code", "3"]].
# 400000 cells are detected by ["RVD", ["rate", "gender"]].
# 396086 cells are detected by ["RVD", ["married_exemp", "child_exemp"]].
# 400000 cells are detected by ["RVD", ["l_name", "salary"]].
# 395702 cells are detected by ["RVD", ["child_exemp", "state"]].
# 400000 cells are detected by ["RVD", ["l_name", "area_code"]].
# 16398 cells are detected by ["PVD", ["f_name", "M"]].
# 20173 cells are detected by ["PVD", ["f_name", "S"]].
# 92659 cells are detected by ["PVD", ["city", "L"]].
# 5010 cells are detected by ["RVD", ["phone", "gender"]].
# 9698 cells are detected by ["PVD", ["f_name", "T"]].
# 4982 cells are detected by ["RVD", ["phone", "has_child"]].
# 46957 cells are detected by ["PVD", ["f_name", "u"]].
# 27360 cells are detected by ["PVD", ["f_name", "d"]].
# 400000 cells are detected by ["RVD", ["salary", "phone"]].
# 39791 cells are detected by ["PVD", ["f_name", "s"]].
# 400000 cells are detected by ["RVD", ["single_exemp", "zip"]].
# 30025 cells are detected by ["PVD", ["city", "P"]].
# 400000 cells are detected by ["RVD", ["married_exemp", "city"]].
# 18970 cells are detected by ["PVD", ["city", "F"]].
# 2482 cells are detected by ["PVD", ["f_name", "X"]].
# 200 cells are detected by ["PVD", ["child_exemp", "*"]].
# 88586 cells are detected by ["PVD", ["l_name", "r"]].
# 1932 cells are detected by ["PVD", ["single_exemp", "6"]].
# 400000 cells are detected by ["RVD", ["married_exemp", "zip"]].
# 50494 cells are detected by ["PVD", ["area_code", "8"]].
# 400000 cells are detected by ["RVD", ["salary", "f_name"]].
# 41437 cells are detected by ["PVD", ["city", "M"]].
# 5029 cells are detected by ["PVD", ["f_name", "F"]].
# 29850 cells are detected by ["PVD", ["salary", "1"]].
# 23322 cells are detected by ["PVD", ["rate", "1"]].
# 269668 cells are detected by ["RVD", ["zip", "area_code"]].
# 12463 cells are detected by ["PVD", ["l_name", "C"]].
# 400000 cells are detected by ["RVD", ["salary", "area_code"]].
# 384332 cells are detected by ["RVD", ["child_exemp", "rate"]].
# 95474 cells are detected by ["OD", ["gaussian", "1.7"]].
# 336676 cells are detected by ["RVD", ["rate", "area_code"]].
# 105183 cells are detected by ["PVD", ["l_name", "a"]].
# 8078 cells are detected by ["PVD", ["f_name", "B"]].
# 399980 cells are detected by ["RVD", ["l_name", "gender"]].
# 8106 cells are detected by ["PVD", ["l_name", "A"]].
# 400000 cells are detected by ["RVD", ["single_exemp", "phone"]].
# 4967 cells are detected by ["PVD", ["city", "J"]].
# 399912 cells are detected by ["RVD", ["f_name", "married_exemp"]].
# 99587 cells are detected by ["PVD", ["f_name", "i"]].
# 399864 cells are detected by ["RVD", ["l_name", "single_exemp"]].
# 71159 cells are detected by ["PVD", ["zip", "9"]].
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-20:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-11:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Process ForkPoolWorker-22:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# Process ForkPoolWorker-19:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# Process ForkPoolWorker-17:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 app_1.run_strategies(d)
#
# File ~/Desktop/HiWi/DaskRahaBaran/raha/original/detection.py:198, in Detection.run_strategies(self, d)
#     196         random.shuffle(algorithm_and_configurations)
#     197         pool = multiprocessing.Pool()
# --> 198         strategy_profiles_list = pool.map(self._strategy_runner_process, algorithm_and_configurations)
#     199         # pool.close()
#     200         # pool.join()
#     201 else:
#     202     for dd in self.HISTORICAL_DATASETS + [d.dictionary]:
#
# File /usr/lib/python3.10/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /usr/lib/python3.10/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /usr/lib/python3.10/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /usr/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /usr/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %% [markdown]
# ### 4. Generating Features
# Raha then generates a feature vector for each data cell based on the output of error detection strategies.

# %%
app_1.generate_features(d)

# %% [markdown]
# ### 5. Building Clusters
# Raha next builds a hierarchical clustering model for our clustering-based sampling approach.

# %%
app_1.build_clusters(d)

# %% [markdown]
# ### 6. Interactive Tuple Sampling and Labeling
# Raha then iteratively samples a tuple. We should label data cells of each sampled tuple.

# %%
while len(d.labeled_tuples) < app_1.LABELING_BUDGET:
    app_1.sample_tuple(d)
    if d.has_ground_truth:
        app_1.label_with_ground_truth(d)
    else:
        print("Label the dirty cells in the following sampled tuple.")
        sampled_tuple = pandas.DataFrame(data=[d.dataframe.iloc[d.sampled_tuple, :]], columns=d.dataframe.columns)
        IPython.display.display(sampled_tuple)
        for j in range(d.dataframe.shape[1]):
            cell = (d.sampled_tuple, j)
            value = d.dataframe.iloc[cell]
            correction = input("What is the correction for value '{}'? Type in the same value if it is not erronous.\n".format(value))
            user_label = 1 if value != correction else 0
            d.labeled_cells[cell] = [user_label, correction]
        d.labeled_tuples[d.sampled_tuple] = 1

# %% [markdown]
# ### 7. Propagating User Labels
# Raha then propagates each user label through its cluster.

# %%
app_1.propagate_labels(d)

# %% [markdown]
# ### 8. Predicting Labels of Data Cells
# Raha then trains and applies one classifier per data column to predict the label of the rest of data cells.

# %%
app_1.predict_labels(d)

# %% [markdown]
# ### 9. Storing Results
# Raha can also store the error detection results.

# %%
app_1.store_results(d)

# %% [markdown]
# ### 10. Evaluating the Error Detection Task
# We can finally evaluate our error detection task.

# %%
p, r, f = d.get_data_cleaning_evaluation(d.detected_cells)[:3]
print("Raha's performance on {}:\nPrecision = {:.2f}\nRecall = {:.2f}\nF1 = {:.2f}".format(d.name, p, r, f))

# %% [markdown]
# # Error Correction with Baran

# %% [markdown]
# ### 1. Instantiating the Correction Class
# We first instantiate the `Correction` class.

# %%
app_2 = raha.dask_version.correction_parallel.Correction()

# How many tuples would you label?
app_2.LABELING_BUDGET = 20

# Would you like to see the logs?
app_2.VERBOSE = True

# %% [markdown]
# ### 2. Initializing the Dataset Object
# We next initialize the dataset object.

# %%
d = app_2.initialize_dataset(d)
d.dataframe.head()

# %% [markdown]
# ### 3. Initializing the Error Corrector Models
# Baran initializes the error corrector models.

# %%
app_2.initialize_models(d)

# %% [markdown]
# ### 4. Interactive Tuple Sampling, Labeling, Model updating, Feature Generation, and Correction Prediction
# Baran then iteratively samples a tuple. We should label data cells of each sampled tuple. It then udpates the models accordingly and generates a feature vector for each pair of a data error and a correction candidate. Finally, it trains and applies a classifier to each data column to predict the final correction of each data error. Since we already labeled tuples for Raha, we use the same labeled tuples and do not label new tuples here.

# %%
# while len(d.labeled_tuples) < app_2.LABELING_BUDGET:
#     app_2.sample_tuple(d)
#     if d.has_ground_truth:
#         app_2.label_with_ground_truth(d)
#     else:
#         print("Label the dirty cells in the following sampled tuple.")
#         sampled_tuple = pandas.DataFrame(data=[d.dataframe.iloc[d.sampled_tuple, :]], columns=d.dataframe.columns)
#         IPython.display.display(sampled_tuple)
#         for j in range(d.dataframe.shape[1]):
#             cell = (d.sampled_tuple, j)
#             value = d.dataframe.iloc[cell]
#             correction = input("What is the correction for value '{}'? Type in the same value if it is not erronous.\n".format(value))
#             user_label = 1 if value != correction else 0
#             d.labeled_cells[cell] = [user_label, correction]
#         d.labeled_tuples[d.sampled_tuple] = 1
#     app_2.update_models(d)
#     app_2.predict_corrections(d)

for si in d.labeled_tuples:
    d.sampled_tuple = si
    app_2.update_models(d)
    app_2.predict_corrections(d)

# %% [markdown]
# ### 5. Storing Results
# Baran can also store the error correction results.

# %%
app_2.store_results(d)

# %% [markdown]
# ### 6. Evaluating the Error Correction Task
# We can finally evaluate our error correction task.

# %%
p, r, f = d.get_data_cleaning_evaluation(d.corrected_cells)[-3:]
print("Baran's performance on {}:\nPrecision = {:.2f}\nRecall = {:.2f}\nF1 = {:.2f}".format(d.name, p, r, f))
